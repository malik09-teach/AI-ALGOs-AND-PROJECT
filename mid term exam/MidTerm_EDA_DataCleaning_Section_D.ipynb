# %%
# StudentName=malik abbas khan ,
#  Registration=24pwbcs1190,
#  Section= D, 
# Assigned_DatasetName=pharmacy_drug_sales

# %% [markdown]
# # Phase 1: Meet Your Data (Exploration)
# Goal: Look around and understand what information you have before changing anything.
#
# ### Step 1: Bring the Data Inside
# First, we need to load the data into Python using Pandas.

# %%
#import Libraries
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
# Load your specific dataset

data=pd.read_csv()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Load your specific dataset
# ----> 3 data=pd.read_csv()
#
# TypeError: read_csv() missing 1 required positional argument: 'filepath_or_buffer'

# %% [markdown]
# ### Step 2: Take a Quick Peek & Measure

# %%
# Look at the top 5 rows

# %%
# Print (number of rows, number of columns)

# %% [markdown]
# ### Step 3: Check Data Types & Basic Math
# Are your numbers acting like numbers? Are there any impossible values (like an age of 200)?

# %%
# Shows column names, blank counts, and data types

# %%
# Summarizes the math (min, max, average) for number columns

# %% [markdown]
# ### Step 4: The Deep Dive (Categorical Grouping)
# Let's see the breakdown of your text columns. Is your data balanced, or does one category dominate everything else?

# %%
# Pick a categorical column and count how many times each category appears

# %%
# Group the data to find averages! (e.g., Average output by any categorical column)

# %% [markdown]
# # Phase 2: Clean the Mess (Data Cleaning)
# Goal: Fix errors, fill in blanks, and remove impossible outliers.
#
# ### Step 5: Find and Fix Missing Data (Nulls)
# If the person collecting data left a box blank, Python calls it NaN. You must fix these!

# %%
# Count how many blanks are in each column

# %%
# Choice A: For text columns, fill blanks with the word "Unknown"

# %%
# Choice B: For number columns, fill blanks with the median (the middle number)

# %% [markdown]
# ### Step 6: Remove Copycats (Duplicates)

# %%
# Check for duplicates and drop them

# %% [markdown]
# ### Step 7: Standardize Text
# Sometimes people type "New York", "new york", or " NY ". Let's force everything to be lowercase and remove accidental spaces.

# %%
# Make text lowercase and strip hidden spaces

# %% [markdown]
# ### Step 8: Handle Outliers (Impossible Numbers)
# Did you find a crazy number in Step 3? (Like a flight delayed by -500 minutes). Use a filter to remove rows that don't make sense.

# %%
# Example: Keep only rows where the Price is greater than 0

# %% [markdown]
# # Phase 3: Upgrade Your Data (Feature Engineering)
# Goal: Create new, useful information out of the data you already have.
#
# ### Step 9: Time Travel (Fixing Dates)
# If your dataset has a date column, Pandas probably thinks it's just a regular word (object). Let's convert it to a real time-stamp and extract the month!

# %%
# Convert a text date into a real Python Datetime

# %%
# Create a brand new column that just contains the Month (1 through 12)

# %% [markdown]
# ### Step 10: Create a New Feature (Math Logic)
# Create a brand new column by doing math on existing columns. (For example, calculating "Total Cost" by multiplying Price and Quantity, or making a "Price per Square Foot" column).

# %%
# Create a new column by dividing or multiplying two others

# %% [markdown]
# # Phase 4: Prepare for Machine Learning (Preprocessing)
# Goal: Algorithms only understand standardized numbers. Let's translate.
#
# ### Step 11: Encode Categorical (Text) Data
# If you have a column with categories (like "Red", "Blue", "Green"), Machine Learning models need them to be 1s and 0s.

# %%
# Convert text categories into separate columns of 1s and 0s (One-Hot Encoding)

# %% [markdown]
# # Phase 5: Paint a Picture (Data Visualization)
# Goal: Create professional charts to prove you understand the patterns in the data.
#
# ### Step 12: The Distribution & Outlier Check
# Let's see how your most important numbers are spread out using two plots side-by-side!

# %%
# fig, ax = plt.subplots(1, 2, figsize=(12, 5))


# Plot 1: Histogram (The Spread)


# Plot 2: Boxplot (To spot outliers)

# %% [markdown]
# ### Step 13: Relationships (Scatter Plot)
# Do two columns affect each other? Let's draw a scatter plot with a trendline.

# %%
# draw: Relationships (Scatter Plot)

# %% [markdown]
# ### Step 14: The Big Picture (Correlation Heatmap)
# This colorful chart shows you how every number column is related to every other number column.

# %%
# plt.figure(figsize=(10,6))
# Only correlate number columns (ignore text)

# Draw the heatmap

# %% [markdown]
# # Phase 7: Bivariate Analysis (Two Variables Together)
# Find out how two columns interact with each other
# - Does one go up when the other goes up?
# - Does one category always have a higher value?

# %% [markdown]
# ### Step 15: Numerical vs Numerical — Scatter Plot with Trendline
# Pick any two number columns and plot them against each other.

# %%
# Scatter plot with a linear trendline between two numerical columns

# %% [markdown]
# ### Step 16: Categorical vs Categorical — Cross Tabulation (Pivot Table)
# When you have two category columns, a cross-tabulation counts how many rows fall into every possible combination.

# %%
# Cross Tabulation between two categorical columns

# %% [markdown]
# # Phase 8: Save and Check
# ### Step 17: Save the Clean Data
# Don't overwrite your messy original file! Save the clean version.

# %%
# Save as a new file (Name_RegID_DatasetNumber_DatasetName.csv)

# %% [markdown]
# # Final Check: Verify & Describe the Clean Dataset
# After all the cleaning, engineering, and analysis
# - Take one last look at your data to confirm everything looks correct before you hand it off or use it for modelling.

# %% [markdown]
# ### Step 18: Recheck the Head (Does It Look Right?)
# Print the first few rows of the **final cleaned dataset**.

# %%
# Print the top 5 rows of the cleaned dataset

# %% [markdown]
# ### Step 19: Recheck Shape & Column Names

# %%
# Confirm final dimensions and list all column names

# %% [markdown]
# ### Step 20: Final Describe — Statistical Summary of the Clean Data

# %%
# Final statistical summary — compare this to your original Step 3 output

# %% [markdown]
# ### Step 21: Final Null Check — Confirm Zero Missing Values
# There should be **no nulls left**.

# %%
# Final null audit — all values should be 0

# %% [markdown]
# ### Step 22: Final Data Types Check
# Make sure every column is stored as the **correct data type** after all transformations:

# %%
# Confirm data types of all columns after cleaning and feature engineering
